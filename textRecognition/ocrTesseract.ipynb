# %% [markdown]
# Text Recognition using Tesseract

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

pytesseract.pytesseract.tesseract_cmd = "C:\\Users\\rodrsouza\\AppData\\Local\\Tesseract-OCR\\tesseract.exe"

# %%
img = cv2.imread('imgtext1.png')
plt.imshow(img)

# %%
print(pytesseract.image_to_string(img))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\RODRSO~1\AppData\Local\Temp/ipykernel_10796/1175915332.py in <module>
# ----> 1 print(image_to_string(img))
#
# NameError: name 'image_to_string' is not defined
